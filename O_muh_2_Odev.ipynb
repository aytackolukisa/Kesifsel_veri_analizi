# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sqlalchemy import create_engine
import warnings

# %%
education_df = pd.read_csv("/Users/aytackolukisa/Desktop/Jupiter_Dosyaları/states_all.csv")
education_df.head()
# Out:
#        PRIMARY_KEY       STATE  YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992     NaN      2678885.0         304177.0
# 1      1992_ALASKA      ALASKA  1992     NaN      1049591.0         106780.0
# 2     1992_ARIZONA     ARIZONA  1992     NaN      3258079.0         297888.0
# 3    1992_ARKANSAS    ARKANSAS  1992     NaN      1711959.0         178571.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992     NaN     26260025.0        2072470.0
#
#    STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0      1659028.0       715680.0          2653798.0                1481703.0
# 1       720711.0       222100.0           972488.0                 498362.0
# 2      1369815.0      1590376.0          3401580.0                1435908.0
# 3       958785.0       574603.0          1743022.0                 964323.0
# 4     16546514.0      7641041.0         27138832.0               14358922.0
#
# ...

# %%
a = education_df.columns
liste = [i for i in a]
liste.remove("PRIMARY_KEY")
liste.remove("STATE")

# %%
states = education_df["STATE"].unique()

for state in states:
    education_df.loc[education_df["STATE"] == state, liste] = education_df.loc[education_df["STATE"] == state, liste].interpolate()

# we drop the null values after interpolation
education_df.dropna(inplace=True)

# %%
education_df["overall_score"] = (education_df["GRADES_4_G"]* 
                                 ((education_df["AVG_MATH_4_SCORE"] + education_df["AVG_READING_4_SCORE"]) * 0.5) + 
                                 education_df["GRADES_8_G"]
                                 * ((education_df["AVG_MATH_8_SCORE"] + 
                                     education_df["AVG_READING_8_SCORE"]) * 
                                    0.5))/ (education_df["GRADES_4_G"] + education_df["GRADES_8_G"])

# %%
education_df.head()
# Out:
#          PRIMARY_KEY       STATE  YEAR     ENROLL  TOTAL_REVENUE  \
# 306     1998_ALABAMA     ALABAMA  1998   739321.0      4140537.0
# 307      1998_ALASKA      ALASKA  1998   130633.0      1206195.0
# 308     1998_ARIZONA     ARIZONA  1998   794331.0      4675296.0
# 309    1998_ARKANSAS    ARKANSAS  1998   456355.0      2567380.0
# 310  1998_CALIFORNIA  CALIFORNIA  1998  5727224.0     39183018.0
#
#      FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# 306         374153.0      2589819.0      1176565.0          4245033.0
# 307         157335.0       745814.0       303046.0          1222893.0
# 308         470398.0      2000801.0      2204097.0          4726098.0
# 309         226475.0      1505419.0       835486.0          2536027.0
# 310        3149260.0     22840500.0     13193258.0         38087666.0
#
#      INSTRUCTION_EXPENDITURE  ...  GRADES_8_G  GRADES_12_G  GRADES_1_8_G  \
# 306                2218693.0  ...     57105.0      43957.0      473954.0
# ...

# %%
new_list = ["overall_score",'TOTAL_EXPENDITURE',
 'INSTRUCTION_EXPENDITURE',
 'SUPPORT_SERVICES_EXPENDITURE',
 'OTHER_EXPENDITURE',
 'CAPITAL_OUTLAY_EXPENDITURE']

# %%
education_df[["overall_score",'TOTAL_EXPENDITURE',
 'INSTRUCTION_EXPENDITURE',
 'SUPPORT_SERVICES_EXPENDITURE',
 'OTHER_EXPENDITURE',
 'CAPITAL_OUTLAY_EXPENDITURE']].corr()
# Out:
#                               overall_score  TOTAL_EXPENDITURE  \
# overall_score                      1.000000           0.038725
# TOTAL_EXPENDITURE                  0.038725           1.000000
# INSTRUCTION_EXPENDITURE            0.051139           0.990278
# SUPPORT_SERVICES_EXPENDITURE       0.043430           0.991591
# OTHER_EXPENDITURE                 -0.015947           0.943874
# CAPITAL_OUTLAY_EXPENDITURE        -0.035727           0.920782
#
#                               INSTRUCTION_EXPENDITURE  \
# overall_score                                0.051139
# TOTAL_EXPENDITURE                            0.990278
# INSTRUCTION_EXPENDITURE                      1.000000
# SUPPORT_SERVICES_EXPENDITURE                 0.972066
# OTHER_EXPENDITURE                            0.900803
# CAPITAL_OUTLAY_EXPENDITURE                   0.879846
#
#                               SUPPORT_SERVICES_EXPENDITURE  OTHER_EXPENDITURE  \
# ...

# %% [markdown]
# overall_score ile ilişkisi en yüksek değişken INSTRUCTION_EXPENDITURE

# %%
X = education_df[["INSTRUCTION_EXPENDITURE", "SUPPORT_SERVICES_EXPENDITURE",
                  "OTHER_EXPENDITURE", "CAPITAL_OUTLAY_EXPENDITURE"]]

X = StandardScaler().fit_transform(X)

sklearn_pca = PCA(n_components=1)
education_df["pca_1"] = sklearn_pca.fit_transform(X)

print(
    'The percentage of total variance in the dataset explained by each',
    'component from Sklearn PCA.\n',
    sklearn_pca.explained_variance_ratio_
)
# Out:
# The percentage of total variance in the dataset explained by each component from Sklearn PCA.
#  [0.94088389]

# %%
education_df[["overall_score", "pca_1", "TOTAL_EXPENDITURE", "INSTRUCTION_EXPENDITURE",
              "SUPPORT_SERVICES_EXPENDITURE", "OTHER_EXPENDITURE", "CAPITAL_OUTLAY_EXPENDITURE"]].corr()
# Out:
#                               overall_score     pca_1  TOTAL_EXPENDITURE  \
# overall_score                      1.000000  0.011373           0.038725
# pca_1                              0.011373  1.000000           0.991595
# TOTAL_EXPENDITURE                  0.038725  0.991595           1.000000
# INSTRUCTION_EXPENDITURE            0.051139  0.967482           0.990278
# SUPPORT_SERVICES_EXPENDITURE       0.043430  0.987095           0.991591
# OTHER_EXPENDITURE                 -0.015947  0.972319           0.943874
# CAPITAL_OUTLAY_EXPENDITURE        -0.035727  0.952760           0.920782
#
#                               INSTRUCTION_EXPENDITURE  \
# overall_score                                0.051139
# pca_1                                        0.967482
# TOTAL_EXPENDITURE                            0.990278
# INSTRUCTION_EXPENDITURE                      1.000000
# SUPPORT_SERVICES_EXPENDITURE                 0.972066
# OTHER_EXPENDITURE                            0.900803
# ...

# %% [markdown]
# pca_1 in overall_score ile korelasyonu çok düşük ve pca_1 i oluşturan diğer değişkenler ile korelasyonu 0.8 den büyük bu kararsız temeş bileşenler tahmininene yol açabilir.
