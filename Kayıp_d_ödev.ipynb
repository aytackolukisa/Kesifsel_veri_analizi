# %%
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("/Users/aytackolukisa/Desktop/Jupiter_Dosyaları/states_all_extended.csv")

# %%
data.head(5)
# Out:
#        PRIMARY_KEY       STATE  YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992     NaN      2678885.0         304177.0
# 1      1992_ALASKA      ALASKA  1992     NaN      1049591.0         106780.0
# 2     1992_ARIZONA     ARIZONA  1992     NaN      3258079.0         297888.0
# 3    1992_ARKANSAS    ARKANSAS  1992     NaN      1711959.0         178571.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992     NaN     26260025.0        2072470.0
#
#    STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0      1659028.0       715680.0          2653798.0                1481703.0
# 1       720711.0       222100.0           972488.0                 498362.0
# 2      1369815.0      1590376.0          3401580.0                1435908.0
# 3       958785.0       574603.0          1743022.0                 964323.0
# 4     16546514.0      7641041.0         27138832.0               14358922.0
#
# ...

# %%
data.tail(5)
# Out:
#              PRIMARY_KEY          STATE  YEAR  ENROLL  TOTAL_REVENUE  \
# 1710       2019_VIRGINIA       VIRGINIA  2019     NaN            NaN
# 1711     2019_WASHINGTON     WASHINGTON  2019     NaN            NaN
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019     NaN            NaN
# 1713      2019_WISCONSIN      WISCONSIN  2019     NaN            NaN
# 1714        2019_WYOMING        WYOMING  2019     NaN            NaN
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# 1710              NaN            NaN            NaN                NaN
# 1711              NaN            NaN            NaN                NaN
# 1712              NaN            NaN            NaN                NaN
# 1713              NaN            NaN            NaN                NaN
# 1714              NaN            NaN            NaN                NaN
#
#       INSTRUCTION_EXPENDITURE  ...  G08_HI_A_READING  G08_HI_A_MATHEMATICS  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1715 entries, 0 to 1714
# Columns: 266 entries, PRIMARY_KEY to G08_TR_A_MATHEMATICS
# dtypes: float64(263), int64(1), object(2)
# memory usage: 3.5+ MB

# %% [markdown]
# ## Veri Türleri:
#     Katagorik_Değişkenler : PRIMARY_KEY,STATE (2 adet)
#     Sürekli_Değikenler(int) : YEAR (1 adet)
#     Sürekli_Değikenler(float) : TOTAL_REVENUE,FEDERAL_REVENUE,.....G08_TR_A_MATHEMATICS (263 adet)

# %%
data.isnull().sum()*100/len(data)
# Out:
# PRIMARY_KEY              0.000000
# STATE                    0.000000
# YEAR                     0.000000
# ENROLL                  28.629738
# TOTAL_REVENUE           25.655977
#                           ...
# G08_AM_A_MATHEMATICS    96.501458
# G08_HP_A_READING        99.183673
# G08_HP_A_MATHEMATICS    99.241983
# G08_TR_A_READING        91.778426
# G08_TR_A_MATHEMATICS    91.545190
# Length: 266, dtype: float64

# %% [markdown]
# youtube["video_sayisi"].fillna(youtube["video_sayisi"].mean(), inplace=True)

# %%
df = data.drop(["PRIMARY_KEY","STATE"],axis=1)

# %%
df
# Out:
#       YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  STATE_REVENUE  \
# 0     1992     NaN      2678885.0         304177.0      1659028.0
# 1     1992     NaN      1049591.0         106780.0       720711.0
# 2     1992     NaN      3258079.0         297888.0      1369815.0
# 3     1992     NaN      1711959.0         178571.0       958785.0
# 4     1992     NaN     26260025.0        2072470.0     16546514.0
# ...    ...     ...            ...              ...            ...
# 1710  2019     NaN            NaN              NaN            NaN
# 1711  2019     NaN            NaN              NaN            NaN
# 1712  2019     NaN            NaN              NaN            NaN
# 1713  2019     NaN            NaN              NaN            NaN
# 1714  2019     NaN            NaN              NaN            NaN
#
#       LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0          715680.0          2653798.0                1481703.0
# ...

# %%
def filling_by_mean(x):
    df[x].fillna(df[x].mean(), inplace=True)

# %%
liste = df.columns

# %%
for c in liste:
    filling_by_mean(c)

# %%
df
# Out:
#       YEAR         ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  STATE_REVENUE  \
# 0     1992  917541.566176   2.678885e+06     3.041770e+05   1.659028e+06
# 1     1992  917541.566176   1.049591e+06     1.067800e+05   7.207110e+05
# 2     1992  917541.566176   3.258079e+06     2.978880e+05   1.369815e+06
# 3     1992  917541.566176   1.711959e+06     1.785710e+05   9.587850e+05
# 4     1992  917541.566176   2.626002e+07     2.072470e+06   1.654651e+07
# ...    ...            ...            ...              ...            ...
# 1710  2019  917541.566176   9.102045e+06     7.677799e+05   4.223743e+06
# 1711  2019  917541.566176   9.102045e+06     7.677799e+05   4.223743e+06
# 1712  2019  917541.566176   9.102045e+06     7.677799e+05   4.223743e+06
# 1713  2019  917541.566176   9.102045e+06     7.677799e+05   4.223743e+06
# 1714  2019  917541.566176   9.102045e+06     7.677799e+05   4.223743e+06
#
#       LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# ...

# %%
data
# Out:
#              PRIMARY_KEY          STATE  YEAR  ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992     NaN      2678885.0
# 1            1992_ALASKA         ALASKA  1992     NaN      1049591.0
# 2           1992_ARIZONA        ARIZONA  1992     NaN      3258079.0
# 3          1992_ARKANSAS       ARKANSAS  1992     NaN      1711959.0
# 4        1992_CALIFORNIA     CALIFORNIA  1992     NaN     26260025.0
# ...                  ...            ...   ...     ...            ...
# 1710       2019_VIRGINIA       VIRGINIA  2019     NaN            NaN
# 1711     2019_WASHINGTON     WASHINGTON  2019     NaN            NaN
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019     NaN            NaN
# 1713      2019_WISCONSIN      WISCONSIN  2019     NaN            NaN
# 1714        2019_WYOMING        WYOMING  2019     NaN            NaN
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# ...

# %%
for c in liste:
    data[c]=df[c]

# %%
data.head(20)
# Out:
#                   PRIMARY_KEY                 STATE  YEAR         ENROLL  \
# 0                1992_ALABAMA               ALABAMA  1992  917541.566176
# 1                 1992_ALASKA                ALASKA  1992  917541.566176
# 2                1992_ARIZONA               ARIZONA  1992  917541.566176
# 3               1992_ARKANSAS              ARKANSAS  1992  917541.566176
# 4             1992_CALIFORNIA            CALIFORNIA  1992  917541.566176
# 5               1992_COLORADO              COLORADO  1992  917541.566176
# 6            1992_CONNECTICUT           CONNECTICUT  1992  917541.566176
# 7               1992_DELAWARE              DELAWARE  1992  917541.566176
# 8   1992_DISTRICT_OF_COLUMBIA  DISTRICT_OF_COLUMBIA  1992  917541.566176
# 9                1992_FLORIDA               FLORIDA  1992  917541.566176
# 10               1992_GEORGIA               GEORGIA  1992  917541.566176
# 11                1992_HAWAII                HAWAII  1992  917541.566176
# ...

# %% [markdown]
# % 90 ı "nan" olan bir variable ı sample almadan veya katagoriye ayırmadan doldurmanın bir anlamı yok

# %%
data_2 = pd.read_csv("/Users/aytackolukisa/Desktop/Jupiter_Dosyaları/states_all_extended.csv")

# %%
data_2.head(5)
# Out:
#        PRIMARY_KEY       STATE  YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992     NaN      2678885.0         304177.0
# 1      1992_ALASKA      ALASKA  1992     NaN      1049591.0         106780.0
# 2     1992_ARIZONA     ARIZONA  1992     NaN      3258079.0         297888.0
# 3    1992_ARKANSAS    ARKANSAS  1992     NaN      1711959.0         178571.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992     NaN     26260025.0        2072470.0
#
#    STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0      1659028.0       715680.0          2653798.0                1481703.0
# 1       720711.0       222100.0           972488.0                 498362.0
# 2      1369815.0      1590376.0          3401580.0                1435908.0
# 3       958785.0       574603.0          1743022.0                 964323.0
# 4     16546514.0      7641041.0         27138832.0               14358922.0
#
# ...

# %%
a=data_2.groupby('YEAR')['ENROLL'].mean()

# %%
a
# Out:
# YEAR
# 1986              NaN
# 1987              NaN
# 1988              NaN
# 1989              NaN
# 1990              NaN
# 1991              NaN
# 1992              NaN
# 1993    802054.333333
# 1994    801383.960784
# 1995    858973.039216
# 1996    873930.607843
# 1997    888379.745098
# 1998    897509.058824
# 1999    905101.470588
# 2000    910446.705882
# 2001    916296.274510
# 2002    923818.196078
# 2003    933396.862745
# 2004    938327.117647
# 2005    942259.960784
# 2006    947078.980392
# 2007    949109.254902
# 2008    949047.392157
# 2009    946249.313725
# 2010    946396.254902
# 2011    946587.745098
# 2012    945379.392157
# 2013    947012.176471
# 2014    948607.529412
# 2015    951263.450980
# 2016    952388.764706
# 2017              NaN
# 2019              NaN
# Name: ENROLL, dtype: float64

# %%
a.values[0]
# Out:
# nan

# %%
len(a)
# Out:
# 33

# %%
def ortalama (variable):
    a=df1.groupby('YEAR')[variable].mean()
    liste=np.arange(len(a))
    for i in liste :
        data_2[variable].fillna(a.values[i], inplace = True)

# %%
a
# Out:
# YEAR
# 1986              NaN
# 1987              NaN
# 1988              NaN
# 1989              NaN
# 1990              NaN
# 1991              NaN
# 1992              NaN
# 1993    802054.333333
# 1994    801383.960784
# 1995    858973.039216
# 1996    873930.607843
# 1997    888379.745098
# 1998    897509.058824
# 1999    905101.470588
# 2000    910446.705882
# 2001    916296.274510
# 2002    923818.196078
# 2003    933396.862745
# 2004    938327.117647
# 2005    942259.960784
# 2006    947078.980392
# 2007    949109.254902
# 2008    949047.392157
# 2009    946249.313725
# 2010    946396.254902
# 2011    946587.745098
# 2012    945379.392157
# 2013    947012.176471
# 2014    948607.529412
# 2015    951263.450980
# 2016    952388.764706
# 2017              NaN
# 2019              NaN
# Name: ENROLL, dtype: float64

# %%
a.values[0]
# Out:
# nan

# %%
df1 = data_2.drop(["PRIMARY_KEY","STATE"],axis=1)

# %%
liste_3 =df1.columns

# %%
for x in liste_3:
    ortalama(x)

# %%
df1
# Out:
#       YEAR         ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  STATE_REVENUE  \
# 0     1992  802054.333333   2.678885e+06     3.041770e+05   1.659028e+06
# 1     1992  802054.333333   1.049591e+06     1.067800e+05   7.207110e+05
# 2     1992  802054.333333   3.258079e+06     2.978880e+05   1.369815e+06
# 3     1992  802054.333333   1.711959e+06     1.785710e+05   9.587850e+05
# 4     1992  802054.333333   2.626002e+07     2.072470e+06   1.654651e+07
# ...    ...            ...            ...              ...            ...
# 1710  2019  802054.333333   4.572764e+06     2.970296e+05   2.088314e+06
# 1711  2019  802054.333333   4.572764e+06     2.970296e+05   2.088314e+06
# 1712  2019  802054.333333   4.572764e+06     2.970296e+05   2.088314e+06
# 1713  2019  802054.333333   4.572764e+06     2.970296e+05   2.088314e+06
# 1714  2019  802054.333333   4.572764e+06     2.970296e+05   2.088314e+06
#
#       LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# ...

# %%
liste = df1.columns

# %%
for c in liste:
    data_2[c]=df1[c]

# %%
data_2
# Out:
#              PRIMARY_KEY          STATE  YEAR         ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992  802054.333333   2.678885e+06
# 1            1992_ALASKA         ALASKA  1992  802054.333333   1.049591e+06
# 2           1992_ARIZONA        ARIZONA  1992  802054.333333   3.258079e+06
# 3          1992_ARKANSAS       ARKANSAS  1992  802054.333333   1.711959e+06
# 4        1992_CALIFORNIA     CALIFORNIA  1992  802054.333333   2.626002e+07
# ...                  ...            ...   ...            ...            ...
# 1710       2019_VIRGINIA       VIRGINIA  2019  802054.333333   4.572764e+06
# 1711     2019_WASHINGTON     WASHINGTON  2019  802054.333333   4.572764e+06
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019  802054.333333   4.572764e+06
# 1713      2019_WISCONSIN      WISCONSIN  2019  802054.333333   4.572764e+06
# 1714        2019_WYOMING        WYOMING  2019  802054.333333   4.572764e+06
#
# ...

# %%
data
# Out:
#              PRIMARY_KEY          STATE  YEAR         ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992  917541.566176   2.678885e+06
# 1            1992_ALASKA         ALASKA  1992  917541.566176   1.049591e+06
# 2           1992_ARIZONA        ARIZONA  1992  917541.566176   3.258079e+06
# 3          1992_ARKANSAS       ARKANSAS  1992  917541.566176   1.711959e+06
# 4        1992_CALIFORNIA     CALIFORNIA  1992  917541.566176   2.626002e+07
# ...                  ...            ...   ...            ...            ...
# 1710       2019_VIRGINIA       VIRGINIA  2019  917541.566176   9.102045e+06
# 1711     2019_WASHINGTON     WASHINGTON  2019  917541.566176   9.102045e+06
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019  917541.566176   9.102045e+06
# 1713      2019_WISCONSIN      WISCONSIN  2019  917541.566176   9.102045e+06
# 1714        2019_WYOMING        WYOMING  2019  917541.566176   9.102045e+06
#
# ...

# %%
data_e = pd.read_csv("/Users/aytackolukisa/Desktop/Jupiter_Dosyaları/states_all_extended.csv")

# %%
def enterpolasyon (variabel):
    liste = np.arange(len (data_e1))
    for i in liste:
        if data_e1[variabel][i] ==  "nan":
            data_e1[variabel][i] == ( data_e1[variabel][i-1] + data_e1[variabel][i+1])/2

# %%
data_e1 = data_e.drop(["PRIMARY_KEY","STATE"],axis=1)

# %%
liste4 = data_e1.columns

# %%
for c in liste4:
    enterpolasyon(c)

# %%
liste5 = data_e1.columns

# %%
for x in liste4:
    data_e[x]=data_e1[x]

# %%
data_e
# Out:
#              PRIMARY_KEY          STATE  YEAR  ENROLL  TOTAL_REVENUE  \
# 0           1992_ALABAMA        ALABAMA  1992     NaN      2678885.0
# 1            1992_ALASKA         ALASKA  1992     NaN      1049591.0
# 2           1992_ARIZONA        ARIZONA  1992     NaN      3258079.0
# 3          1992_ARKANSAS       ARKANSAS  1992     NaN      1711959.0
# 4        1992_CALIFORNIA     CALIFORNIA  1992     NaN     26260025.0
# ...                  ...            ...   ...     ...            ...
# 1710       2019_VIRGINIA       VIRGINIA  2019     NaN            NaN
# 1711     2019_WASHINGTON     WASHINGTON  2019     NaN            NaN
# 1712  2019_WEST_VIRGINIA  WEST_VIRGINIA  2019     NaN            NaN
# 1713      2019_WISCONSIN      WISCONSIN  2019     NaN            NaN
# 1714        2019_WYOMING        WYOMING  2019     NaN            NaN
#
#       FEDERAL_REVENUE  STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# ...
